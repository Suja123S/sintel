# %%
from __future__ import print_function
import os
data_path = ['data']

# %%
import pandas as pd

# Import the data using the file path
filepath = os.sep.join(data_path + ['world happiness.csv'])
data = pd.read_csv('world happiness.csv')
data
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# 2                                51.60                         0.600
# 3                                51.92                         0.496
# 4                                52.24                         0.531
# ...                                ...                           ...
# 1944                             54.40                         0.733
# 1945                             55.00                         0.753
# 1946                             55.60                         0.763
# 1947                             56.20                         0.632
# 1948                             56.80                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0          0.168                      0.882            0.518            0.258
# 1          0.190                      0.850            0.584            0.237
# 2          0.121                      0.707            0.618            0.275
# 3          0.162                      0.731            0.611            0.267
# 4          0.236                      0.776            0.710            0.268
# ...          ...                        ...              ...              ...
# 1944      -0.095                      0.724            0.738            0.209
# 1945      -0.098                      0.751            0.806            0.224
# 1946      -0.068                      0.844            0.710            0.212
# 1947      -0.064                      0.831            0.716            0.235
# 1948      -0.009                      0.789            0.703            0.346
#
# [1949 rows x 11 columns]

# %%
data.head(1).T
# Out:
#                                             0
# Country name                      Afghanistan
# year                                     2008
# Life Ladder                             3.724
# Log GDP per capita                       7.37
# Social support                          0.451
# Healthy life expectancy at birth         50.8
# Freedom to make life choices            0.718
# Generosity                              0.168
# Perceptions of corruption               0.882
# Positive affect                         0.518
# Negative affect                         0.258

# %%
# Remove extraneous columns
data.drop(['year'], axis=1, inplace=True)
data
# Out:
#      Country name  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan        3.724               7.370           0.451
# 1     Afghanistan        4.402               7.540           0.552
# 2     Afghanistan        4.758               7.647           0.539
# 3     Afghanistan        3.832               7.620           0.521
# 4     Afghanistan        3.783               7.705           0.521
# ...           ...          ...                 ...             ...
# 1944     Zimbabwe        3.735               7.984           0.768
# 1945     Zimbabwe        3.638               8.016           0.754
# 1946     Zimbabwe        3.616               8.049           0.775
# 1947     Zimbabwe        2.694               7.950           0.759
# 1948     Zimbabwe        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# 2                                51.60                         0.600
# 3                                51.92                         0.496
# 4                                52.24                         0.531
# ...                                ...                           ...
# 1944                             54.40                         0.733
# 1945                             55.00                         0.753
# 1946                             55.60                         0.763
# 1947                             56.20                         0.632
# 1948                             56.80                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0          0.168                      0.882            0.518            0.258
# 1          0.190                      0.850            0.584            0.237
# 2          0.121                      0.707            0.618            0.275
# 3          0.162                      0.731            0.611            0.267
# 4          0.236                      0.776            0.710            0.268
# ...          ...                        ...              ...              ...
# 1944      -0.095                      0.724            0.738            0.209
# 1945      -0.098                      0.751            0.806            0.224
# 1946      -0.068                      0.844            0.710            0.212
# 1947      -0.064                      0.831            0.716            0.235
# 1948      -0.009                      0.789            0.703            0.346
#
# [1949 rows x 10 columns]

# %%
data.columns
# Out:
# Index(['Country name', 'Life Ladder', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect'],
#       dtype='object')

# %%
# Get a list of all the columns that don't contain the label
x_cols = [x for x in data.columns if x != 'Country name']

# Split the data into two dataframes
data[x_cols]=data[x_cols].fillna(0)
X_data = data[x_cols]
y_data =data[y_cols]
y_data = data['Country name']

# # alternatively:
# X_data = data.copy()
# y_data = X_data.pop('churned')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 7
#       5 data[x_cols]=data[x_cols].fillna(0)
#       6 X_data = data[x_cols]
# ----> 7 y_
#       8 y_data = data['Country name	']
#
# NameError: name 'y_' is not defined

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

knn = knn.fit(X_data, y_data)

y_pred = knn.predict(X_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 5
#       1 from sklearn.neighbors import KNeighborsClassifier
#       3 knn = KNeighborsClassifier(n_neighbors=3)
# ----> 5 knn = knn.fit(X_data, y_data)
#       7 y_pred = knn.predict(X_data)
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/sklearnex/neighbors/knn_classification.py:233, in KNeighborsClassifier.fit(self, X, y)
#     230     self.n_samples_fit_ = X.data.shape[0]
#     231     self.n_features_in_ = X.data.shape[1]
# --> 233 dispatch(self, 'neighbors.KNeighborsClassifier.fit', {
#     234     'onedal': self.__class__._onedal_fit,
#     235     'sklearn': sklearn_KNeighborsClassifier.fit,
#     236 }, X, y)
#     237 return self
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/sklearnex/_device_offload.py:160, in dispatch(obj, method_name, branches, *args, **kwargs)
#     158 logging.info(f"sklearn.{method_name}: {get_patch_message(backend, q, cpu_fallback)}")
#     159 if backend == 'onedal':
# --> 160     return branches[backend](obj, *hostargs, **hostkwargs, queue=q)
#     161 if backend == 'sklearn':
#     162     return branches[backend](obj, *hostargs, **hostkwargs)
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/sklearnex/neighbors/knn_classification.py:413, in KNeighborsClassifier._onedal_fit(self, X, y, queue)
#     411 self._onedal_estimator.effective_metric_ = self.effective_metric_
#     412 self._onedal_estimator.effective_metric_params_ = self.effective_metric_params_
# --> 413 self._onedal_estimator.fit(X, y, queue=queue)
#     415 self._save_attributes()
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/onedal/neighbors/neighbors.py:435, in KNeighborsClassifier.fit(self, X, y, queue)
#     434 def fit(self, X, y, queue=None):
# --> 435     return super()._fit(X, y, queue=queue)
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/onedal/neighbors/neighbors.py:191, in NeighborsBase._fit(self, X, y, queue)
#     189 if y is not None or self.requires_y:
#     190     shape = getattr(y, 'shape', None)
# --> 191     X, y = super()._validate_data(X, y, dtype=[np.float64, np.float32])
#     192     self._shape = shape if shape is not None else y.shape
#     194     if _is_classifier(self):
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/onedal/neighbors/neighbors.py:82, in NeighborsCommonBase._validate_data(self, X, y, reset, validate_separately, **check_params)
#      80         y = _check_array(y, **check_y_params)
#      81     else:
# ---> 82         X, y = _check_X_y(X, y, **check_params)
#      83     out = X, y
#      85 if check_params.get('ensure_2d', True):
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/onedal/datatypes/validation.py:163, in _check_X_y(X, y, dtype, accept_sparse, order, copy, force_all_finite, ensure_2d, accept_large_sparse, y_numeric, accept_2d_y)
#     161 if y_numeric and y.dtype.kind == 'O':
#     162     y = y.astype(np.float64)
# --> 163 assert_all_finite(y)
#     165 lengths = [X.shape[0], y.shape[0]]
#     166 uniques = np.unique(lengths)
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/daal4py/sklearn/utils/validation.py:43, in _daal_assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#      41 if X.size < 32768:
#      42     if sklearn_check_version("1.1"):
# ---> 43         _assert_all_finite(X, allow_nan=allow_nan, msg_dtype=msg_dtype,
#      44                            estimator_name=estimator_name, input_name=input_name)
#      45     else:
#      46         _assert_all_finite(X, allow_nan=allow_nan, msg_dtype=msg_dtype)
#
# File /opt/intel/oneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
# Function to calculate the % of values that were correctly predicted

def accuracy(real, predict):
    return sum(y_data == y_pred) / float(real.shape[0])
